# %% [markdown]
# ## Deep Learning Final Project

# %% [markdown]
# ## Libraries used in this project

# %%
import tensorflow as tf
import torch
import torch.nn as nn
from torchvision import models
import pandas as pd
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import cv2
import glob
import shutil
import os

# %% [markdown]
# ### STEP 1: DATASET PREPARATION
# We will be using the PASCAL VOC2021 DATASET
# - "Annotation" has the XML file
# - "JPEGImages" folder has respective images
# - Required dataset format to implement yolo algorithm:
#     * [Filename, Xmin, Xmax, Ymin, Ymax, Class]

# %%
# Path of the downloaded dataset
annotation_directory = "../VOCdevkit/VOC2012/Annotations"
image_directory = "../VOCdevkit/VOC2012/JPEGImages"
new_train_directory = "./Training_dataset"
train_annotations = './Annotations'

# %%
#For creating new directories
def create_dir(path):
    if not os.path.isdir(path):
        os.mkdir(path)
create_dir(new_train_directory)
create_dir(train_annotations)

# %%
# Collecting the xml files into a list
def data_from_path(path):
    '''Takes path as input and returns list of files data'''
    xml_files=[]
    for filename in os.listdir(path):
        if filename.endswith(".xml"):
            xml_files.append(ET.parse(path+"/"+filename))
    return xml_files

# %%
#xml data from Annotations to list
xml_files = data_from_path(annotation_directory)

# %%
#extract properties of images in Annotations data
def extract_properties(data):
    '''takes list as input and returns properties in a pandas dataframe'''
    # Empty arrays initialization for dataset format
    file_name=[]
    classification=[]
    xmin=[]
    xmax=[]
    ymin=[]
    ymax=[]
    # Iterating the xml file to find objects and its bounding box coordinates
    for i in range(0,len(data)):
        for item in data[i].iterfind('object'):
            for size in item.iterfind('bndbox'):  
                classification.append(item.findtext('name'))
                file_name.append(data[i].findtext('filename'))
                xmin.append(size.findtext('xmin'))
                ymin.append(size.findtext('ymin'))
                xmax.append(size.findtext('xmax'))
                ymax.append(size.findtext('ymax'))
    # Creating dataframe
    properties_pd = pd.DataFrame({'file_name': file_name,'classification':classification, 'xmin':xmin, 'xmax':xmax, 'ymin':ymin, 'ymax':ymax})
    print("Size of different objects in the entire dataset=", len(properties_pd))
    return properties_pd

# %%
properties_pd = extract_properties(xml_files)
properties_pd.head(10)
# Out:
# Size of different objects in the entire dataset= 40138
#          file_name classification xmin xmax ymin ymax
# 0  2007_000027.jpg         person  174  349  101  351
# 1  2007_000032.jpg      aeroplane  104  375   78  183
# 2  2007_000032.jpg      aeroplane  133  197   88  123
# 3  2007_000032.jpg         person  195  213  180  229
# 4  2007_000032.jpg         person   26   44  189  238
# 5  2007_000033.jpg      aeroplane    9  499  107  263
# 6  2007_000033.jpg      aeroplane  421  482  200  226
# 7  2007_000033.jpg      aeroplane  325  411  188  223
# 8  2007_000039.jpg      tvmonitor  156  344   89  279
# 9  2007_000042.jpg          train  263  500   32  295

# %%
# selecting images with just a single object for simplicity
sample_plot_images= properties_pd.drop_duplicates('file_name', keep=False)
print("Size of dataset with just a single image is: ",len(sample_plot_images))
sample_plot_images.head(10)
# Out:
# Size of dataset with just a single image is:  8966
#           file_name classification xmin xmax ymin ymax
# 0   2007_000027.jpg         person  174  349  101  351
# 8   2007_000039.jpg      tvmonitor  156  344   89  279
# 15  2007_000068.jpg           bird   27  266   45  375
# 18  2007_000123.jpg          train    1  358   26  340
# 31  2007_000175.jpg          sheep   25  419   34  271
# 32  2007_000187.jpg      tvmonitor    1  240   95  336
# 36  2007_000243.jpg      aeroplane  181  274  127  193
# 39  2007_000256.jpg      aeroplane    8  491   96  232
# 40  2007_000272.jpg         person   25  304   71  500
# 43  2007_000332.jpg          horse   54  285   50  262

# %%
# Unique classes are
print("Unique classes are: \n",sample_plot_images.classification.unique())
# Out:
# Unique classes are:
#  ['person' 'tvmonitor' 'bird' 'train' 'sheep' 'aeroplane' 'horse' 'cow'
#  'cat' 'dog' 'boat' 'car' 'sofa' 'bicycle' 'diningtable' 'motorbike' 'bus'
#  'pottedplant' 'bottle' 'chair']

# %%
sample_plot_images.groupby(['classification']).agg(['count'])['file_name']
# Out:
#                 count
# classification
# aeroplane         473
# bicycle           160
# bird              568
# boat              182
# bottle            136
# bus               103
# car               288
# cat               745
# chair             119
# cow               123
# diningtable        26
# dog               694
# horse             158
# motorbike         145
# person           4298
# pottedplant        84
# sheep             104
# sofa               85
# train             332
# tvmonitor         143

# %%
#plots specific class to check as the data is more we have selected 2 classes to plot first
def plot_specific_class(data_set, selected_classes,n):
    '''takes data set and list of selected classes and n how many images to plot as input and prints plots of images and returns dataset'''
    # Selecting only PLOTTEDPLANT and SOFA classes for faster computation and balanced dataset
    sample_plot = data_set.loc[data_set['classification'].isin(selected_classes)].reset_index(drop=True)
    print("The number of images in final dataset=",len(sample_plot))
    print(sample_plot.head(10))
    #shows the number of images in each classification
    count_class= sample_plot.groupby(['classification']).agg(['count'])['file_name']
    print(count_class.head(5))
    # drawing bounding boxes limiting to few
    for i in range(0,n):
        f_name = sample_plot.loc[i,"file_name"]
        file_name_split=f_name.split(".")
        xmin=int(sample_plot.loc[i,"xmin"])
        xmax=int(sample_plot.loc[i,"xmax"])
        ymin=int(sample_plot.loc[i,"ymin"])
        ymax=int(sample_plot.loc[i,"ymax"])
        file_name=file_name_split[0]
        image_file = Image.open(image_directory+"/"+file_name+".jpg", "r")
        fig, ax = plt.subplots()
        ax.imshow(image_file)
        bounding_box = patches.Rectangle((xmax,ymax),xmin-xmax, ymin-ymax, linewidth=3, edgecolor='yellow', facecolor='none')
        ax.add_patch(bounding_box)
        plt.show()  
    return sample_plot

# %%
selected_classes = ["pottedplant","sofa"]
n = 10
sample_plot = plot_specific_class(sample_plot_images, selected_classes, n)
# Out:
# The number of images in final dataset= 169
#          file_name classification xmin xmax ymin ymax
# 0  2007_001458.jpg           sofa  106  392  121  299
# 1  2007_003506.jpg    pottedplant   63  261   42  287
# 2  2008_000188.jpg    pottedplant   45  395   59  375
# 3  2008_000923.jpg    pottedplant  226  377  365  491
# 4  2008_001030.jpg           sofa   36  406  205  374
# 5  2008_001399.jpg           sofa    1  315  153  375
# 6  2008_001460.jpg    pottedplant  112  493    1  367
# 7  2008_001663.jpg    pottedplant  174  217  145  190
# 8  2008_001787.jpg           sofa   11  500  269  375
# 9  2008_002273.jpg    pottedplant   56  231  137  308
#                 count
# classification
# pottedplant        84
# sofa               85

# %%
def train_data_subset(data):
    '''Takes data as input and copy subset of them to seperate directory in this case whole data set'''
    # Copy files to new directory for training dataset and test dataset 
    files_to_train=[]
    xml_files = []
    for i in range(0,len(data)):
        files_to_train.append(data.loc[i,"file_name"])
    for file in files_to_train:
        temp = file.split('.')[0] + '.xml'
        xml_files.append(temp)
    for file in files_to_train:
        for jpgfile in glob.iglob(os.path.join(image_directory, file)):
            shutil.copy2(jpgfile, new_train_directory)
    for xml in xml_files:
        for file_xml in glob.iglob(os.path.join(annotation_directory, xml)):
            shutil.copy2(file_xml, train_annotations)
    return files_to_train

# %%
files_to_train = train_data_subset(sample_plot)

# %% [markdown]
# - Required dataset format to implement yolo algorithm:
#     * [Filename, Xmin, Xmax, Ymin, Ymax, Class]

# %%
train_data = sample_plot[['file_name', 'xmin', 'xmax', 'ymin', 'ymax', 'classification']]
train_data.head()
# Out:
#          file_name xmin xmax ymin ymax classification
# 0  2007_001458.jpg  106  392  121  299           sofa
# 1  2007_003506.jpg   63  261   42  287    pottedplant
# 2  2008_000188.jpg   45  395   59  375    pottedplant
# 3  2008_000923.jpg  226  377  365  491    pottedplant
# 4  2008_001030.jpg   36  406  205  374           sofa
